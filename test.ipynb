# %%
import pickle
import json

# Leer el .dict
with open("data/other_mpmt_info.dict", "rb") as f:
    data = pickle.load(f)

# Exportar a JSON
with open("other_mpmt_info.json", "w") as f:
    json.dump(data, f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[11], line 6
#       4 # Leer el .dict
#       5 with open("data/other_mpmt_info.dict", "rb") as f:
# ----> 6     data = pickle.load(f)
#       8 # Exportar a JSON
#       9 with open("other_mpmt_info.json", "w") as f:
#
# EOFError: Ran out of input

# %%
import pickle
import json

with open("data/other_mpmt_info.dict", "rb") as f:
    data = pickle.load(f)

with open("data/other_mpmt_info.json", "w") as f:
    json.dump(data, f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[12], line 5
#       2 import json
#       4 with open("data/other_mpmt_info.dict", "rb") as f:
# ----> 5     data = pickle.load(f)
#       7 with open("data/other_mpmt_info.json", "w") as f:
#       8     json.dump(data, f, indent=4)
#
# EOFError: Ran out of input

# %%
from pathlib import Path

path = Path("data/other_mpmt_info.dict")

print(path.exists())
print(path.stat().st_size if path.exists() else "No existe")
# Out:
# True
# 0
